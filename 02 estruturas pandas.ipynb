# %%
import pandas as pd

# %%
path_csv = "01 dados_exemplo.csv"

dados=pd.read_csv(path_csv)

# %%
dados
# Out:
#      cleNome          Cidade  Idade  Renda Mensal Sexo Estado Civil  \
# 0        Ana        Brasília     62          8599    M        Viúvo
# 1       João          Manaus     18          3496    M     Solteiro
# 2      Maria          Manaus     21          9291    F   Divorciado
# 3      Pedro        Curitiba     21         11200    F     Solteiro
# 4      Lucas  Belo Horizonte     57          1755    M        Viúvo
# 5      Laura        Curitiba     27          1797    F        Viúvo
# 6    Mariana        Brasília     37          1659    M     Solteiro
# 7     Carlos        Curitiba     39          4219    M        Viúvo
# 8      Paula        Brasília     54          9615    F     Solteiro
# 9       José        Salvador     41          8456    M     Solteiro
# 10  Fernanda       Fortaleza     24          4337    F     Solteiro
# 11    Rafael       São Paulo     42          3745    F     Solteiro
# 12   Gabriel          Manaus     42          5735    F   Divorciado
# ...

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados.head()
# Out:
#   cleNome          Cidade  Idade  Renda Mensal Sexo Estado Civil  Qtd Filhos
# 0     Ana        Brasília     62          8599    M        Viúvo           0
# 1    João          Manaus     18          3496    M     Solteiro           1
# 2   Maria          Manaus     21          9291    F   Divorciado           2
# 3   Pedro        Curitiba     21         11200    F     Solteiro           4
# 4   Lucas  Belo Horizonte     57          1755    M        Viúvo           2

# %%
pd.pivot_table(
    dados,
    index='Estado Civil',
    values='cleNome',
    columns='Sexo',
    aggfunc='count'
)
# Out:
# Sexo          F  M
# Estado Civil
# Casado        3  4
# Divorciado    2  1
# Solteiro      6  4
# Viúvo         5  5

# %%
dados[['Cidade']]
# Out:
#             Cidade
# 0         Brasília
# 1           Manaus
# 2           Manaus
# 3         Curitiba
# 4   Belo Horizonte
# 5         Curitiba
# 6         Brasília
# 7         Curitiba
# 8         Brasília
# 9         Salvador
# 10       Fortaleza
# 11       São Paulo
# 12          Manaus
# 13    Porto Alegre
# 14        Brasília
# 15        Salvador
# 16          Manaus
# 17  Belo Horizonte
# 18        Curitiba
# 19          Recife
# 20       Fortaleza
# 21        Salvador
# 22        Curitiba
# 23    Porto Alegre
# 24        Salvador
# 25        Curitiba
# 26        Curitiba
# 27       Fortaleza
# 28          Recife
# 29          Recife
